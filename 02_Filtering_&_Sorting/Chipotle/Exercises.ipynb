# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# 0### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %% [markdown]
#   ### Step 4. How many products cost more than $10.00?

# %%
#clean variable 
chipo['itprice'] = chipo['item_price'].str.replace("$", "")
del chipo['item_price']
chipo.head(30)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
from IPython.display import display
chipping2 = chipo[chipo['quantity'] ==1]


chipping = chipo.pivot_table(index = 'item_name', columns = 'itprice', values = 'quantity', aggfunc = 'count')
display(chipping.head(30))

chipping.shape
# Out:
# itprice                                1.09   1.25   1.50   1.69   1.99   \
# item_name
# 6 Pack Soft Drink                        NaN    NaN    NaN    NaN    NaN
# Barbacoa Bowl                            NaN    NaN    NaN    NaN    NaN
# Barbacoa Burrito                         NaN    NaN    NaN    NaN    NaN
# Barbacoa Crispy Tacos                    NaN    NaN    NaN    NaN    NaN
# Barbacoa Salad Bowl                      NaN    NaN    NaN    NaN    NaN
# Barbacoa Soft Tacos                      NaN    NaN    NaN    NaN    NaN
# Bottled Water                           22.0    NaN  117.0    NaN    NaN
# Bowl                                     NaN    NaN    NaN    NaN    NaN
# Burrito                                  NaN    NaN    NaN    NaN    NaN
# Canned Soda                             84.0    NaN    NaN    NaN    NaN
# Canned Soft Drink                        NaN  264.0    NaN    NaN    NaN
# Carnitas Bowl                            NaN    NaN    NaN    NaN    NaN
# ...

# %%
ch2 = chipping.idxmax(axis = 1)

display(ch2)

ch2.shape
# Out:
# item_name
# 6 Pack Soft Drink                         6.49
# Barbacoa Bowl                             9.25
# Barbacoa Burrito                          9.25
# Barbacoa Crispy Tacos                     9.25
# Barbacoa Salad Bowl                      11.89
# Barbacoa Soft Tacos                       9.25
# Bottled Water                             1.50
# Bowl                                     22.20
# Burrito                                   7.40
# Canned Soda                               1.09
# Canned Soft Drink                         1.25
# Carnitas Bowl                             9.25
# Carnitas Burrito                          9.25
# Carnitas Crispy Tacos                    11.75
# Carnitas Salad                            8.99
# Carnitas Salad Bowl                      11.89
# Carnitas Soft Tacos                       9.25
# Chicken Bowl                              8.75
# Chicken Burrito                           8.75
# Chicken Crispy Tacos                      8.75
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
# see above

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
ch2.sort_index()
# Out:
# item_name
# 6 Pack Soft Drink                         6.49
# Barbacoa Bowl                             9.25
# Barbacoa Burrito                          9.25
# Barbacoa Crispy Tacos                     9.25
# Barbacoa Salad Bowl                      11.89
# Barbacoa Soft Tacos                       9.25
# Bottled Water                             1.50
# Bowl                                     22.20
# Burrito                                   7.40
# Canned Soda                               1.09
# Canned Soft Drink                         1.25
# Carnitas Bowl                             9.25
# Carnitas Burrito                          9.25
# Carnitas Crispy Tacos                    11.75
# Carnitas Salad                            8.99
# Carnitas Salad Bowl                      11.89
# Carnitas Soft Tacos                       9.25
# Chicken Bowl                              8.75
# Chicken Burrito                           8.75
# Chicken Crispy Tacos                      8.75
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by = 'itprice', ascending = False)
# Out:
#       order_id  quantity              item_name  \
# 2624      1042         1       Steak Salad Bowl
# 4419      1762         1       Steak Salad Bowl
# 4036      1615         1       Steak Salad Bowl
# 1825       738         1    Barbacoa Salad Bowl
# 3115      1243         1    Carnitas Salad Bowl
# 4547      1807         1       Steak Salad Bowl
# 3098      1235         1       Steak Salad Bowl
# 4241      1693         1       Steak Salad Bowl
# 1418       576         1    Barbacoa Salad Bowl
# 4391      1752         1       Steak Salad Bowl
# 4572      1818         1       Steak Salad Bowl
# 2600      1032         1       Steak Salad Bowl
# 607        250         1       Steak Salad Bowl
# 4390      1751         1    Barbacoa Salad Bowl
# 1865       756         1    Carnitas Salad Bowl
# 1421       576         1    Barbacoa Salad Bowl
# 3356      1346         1    Barbacoa Salad Bowl
# 1789       724         1    Carnitas Soft Tacos
# ...

# %%
# chipping.get_value('Bowl', '22.20')

# chipping[itprice == 22.20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-176-400d931a8d26> in <module>()
#       1 # chipping.get_value('Bowl', '22.20')
# ----> 2 chipping[itprice == 22.20]
#
# NameError: name 'itprice' is not defined

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name == 'Veggie Salad Bowl'].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# itprice               18
# dtype: int64

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo[(chipo.quantity > 1) & (chipo.item_name == 'Canned Soda')].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# itprice               20
# dtype: int64
